# %% [markdown]
# # Part 1 - Webscraping and Database

# %%
import pymongo
from urllib.request import urlopen
from bs4 import BeautifulSoup, Comment
import pandas as pd
import numpy as np

# %% [markdown]
# We scrape data from https://www.basketball-reference.com/leagues/NBA_2020_games.html

# %%
def get_months(season = 2020):
    year = str(season)
    url = "https://www.basketball-reference.com/leagues/NBA_" + year + "_games.html"
    html = urlopen(url)
    soup = BeautifulSoup(html, 'lxml')
    links = [a['href'] for a in soup.find_all('a', href=True)]
    link_months = [link for link in links if ('NBA_'+year+'_games-' in link) and ('html' in link)]
    return link_months

link_months = get_months()
link_months
# Out:
# ['/leagues/NBA_2020_games-october.html',
#  '/leagues/NBA_2020_games-november.html',
#  '/leagues/NBA_2020_games-december.html',
#  '/leagues/NBA_2020_games-january.html',
#  '/leagues/NBA_2020_games-february.html',
#  '/leagues/NBA_2020_games-march.html',
#  '/leagues/NBA_2020_games-april.html']

# %%
def get_list_of_games(urlarg):
    url = "https://www.basketball-reference.com"+urlarg
    html = urlopen(url)
    soup = BeautifulSoup(html, 'lxml')
    links = [a['href'] for a in soup.find_all('a', href=True)]
    link_bs = [link for link in links if ('boxscore' in link) and ('html' in link)]
    return link_bs

games = []
for i in link_months:
    games = games + get_list_of_games(i)

games
# Out:
# ['/boxscores/201910220TOR.html',
#  '/boxscores/201910220LAC.html',
#  '/boxscores/201910230CHO.html',
#  '/boxscores/201910230IND.html',
#  '/boxscores/201910230ORL.html',
#  '/boxscores/201910230BRK.html',
#  '/boxscores/201910230MIA.html',
#  '/boxscores/201910230PHI.html',
#  '/boxscores/201910230DAL.html',
#  '/boxscores/201910230SAS.html',
#  '/boxscores/201910230UTA.html',
#  '/boxscores/201910230PHO.html',
#  '/boxscores/201910230POR.html',
#  '/boxscores/201910240DET.html',
#  '/boxscores/201910240HOU.html',
#  '/boxscores/201910240GSW.html',
#  '/boxscores/201910250BOS.html',
#  '/boxscores/201910250CHO.html',
#  '/boxscores/201910250BRK.html',
#  '/boxscores/201910250MEM.html',
#  '/boxscores/201910250NOP.html',
#  '/boxscores/201910250OKC.html',
#  '/boxscores/201910250DEN.html',
#  '/boxscores/201910250SAC.html',
#  '/boxscores/201910250LAL.html',
#  '/boxscores/201910260MIL.html',
#  '/boxscores/201910260DET.html',
#  '/boxscores/201910260ATL.html',
#  '/boxscores/201910260NYK.html',
#  '/boxscores/201910260CHI.html',
#  '/boxscores/201910260CLE.html',
#  '/boxscores/201910260HOU.html',
#  '/boxscores/201910260SAS.html',
#  '/boxscores/201910260UTA.html',
#  '/boxscores/201910260PHO.html',
#  '/boxscores/201910270OKC.html',
#  '/boxscores/201910270MEM.html',
#  '/boxscores/201910270DAL.html',
#  '/boxscores/201910270MIN.html',
#  '/boxscores/201910270LAL.html',
#  '/boxscores/201910280NYK.html',
#  '/boxscores/201910280DET.html',
#  '/boxscores/201910280TOR.html',
#  '/boxscores/201910280ATL.html',
#  '/boxscores/201910280HOU.html',
#  '/boxscores/201910280MIL.html',
#  '/boxscores/201910280NOP.html',
#  '/boxscores/201910280SAS.html',
#  '/boxscores/201910280PHO.html',
#  '/boxscores/201910280SAC.html',
#  '/boxscores/201910280LAC.html',
#  '/boxscores/201910290MIA.html',
#  '/boxscores/201910290DEN.html',
#  '/boxscores/201910290LAL.html',
#  '/boxscores/201910300CLE.html',
#  '/boxscores/201910300ORL.html',
#  '/boxscores/201910300PHI.html',
#  '/boxscores/201910300BOS.html',
#  '/boxscores/201910300BRK.html',
#  '/boxscores/201910300TOR.html',
#  '/boxscores/201910300OKC.html',
#  '/boxscores/201910300WAS.html',
#  '/boxscores/201910300SAC.html',
#  '/boxscores/201910300UTA.html',
#  '/boxscores/201910300GSW.html',
#  '/boxscores/201910310ATL.html',
#  '/boxscores/201910310NOP.html',
#  '/boxscores/201910310LAC.html',
#  '/boxscores/201911010BRK.html',
#  '/boxscores/201911010IND.html',
#  '/boxscores/201911010ORL.html',
#  '/boxscores/201911010BOS.html',
#  '/boxscores/201911010CHI.html',
#  '/boxscores/201911010DAL.html',
#  '/boxscores/201911010SAC.html',
#  '/boxscores/201911010GSW.html',
#  '/boxscores/201911020OKC.html',
#  '/boxscores/201911020DET.html',
#  '/boxscores/201911020ORL.html',
#  '/boxscores/201911020MEM.html',
#  '/boxscores/201911020MIL.html',
#  '/boxscores/201911020WAS.html',
#  '/boxscores/201911020GSW.html',
#  '/boxscores/201911020POR.html',
#  '/boxscores/201911030IND.html',
#  '/boxscores/201911030MIA.html',
#  '/boxscores/201911030NYK.html',
#  '/boxscores/201911030SAS.html',
#  '/boxscores/201911030CLE.html',
#  '/boxscores/201911030LAC.html',
#  '/boxscores/201911040WAS.html',
#  '/boxscores/201911040BRK.html',
#  '/boxscores/201911040MEM.html',
#  '/boxscores/201911040MIN.html',
#  '/boxscores/201911040PHO.html',
#  '/boxscores/201911040GSW.html',
#  '/boxscores/201911050CHO.html',
#  '/boxscores/201911050CLE.html',
#  '/boxscores/201911050ATL.html',
#  '/boxscores/201911050CHI.html',
#  '/boxscores/201911050OKC.html',
#  '/boxscores/201911050DEN.html',
#  '/boxscores/201911060DET.html',
#  '/boxscores/201911060IND.html',
#  '/boxscores/201911060ATL.html',
#  '/boxscores/201911060HOU.html',
#  '/boxscores/201911060TOR.html',
#  '/boxscores/201911060MEM.html',
#  '/boxscores/201911060DAL.html',
#  '/boxscores/201911060UTA.html',
#  '/boxscores/201911060LAC.html',
#  '/boxscores/201911070CHO.html',
#  '/boxscores/201911070SAS.html',
#  '/boxscores/201911070PHO.html',
#  '/boxscores/201911070LAC.html',
#  '/boxscores/201911080IND.html',
#  '/boxscores/201911080ORL.html',
#  '/boxscores/201911080WAS.html',
#  '/boxscores/201911080ATL.html',
#  '/boxscores/201911080MIN.html',
#  '/boxscores/201911080NOP.html',
#  '/boxscores/201911080DAL.html',
#  '/boxscores/201911080DEN.html',
#  '/boxscores/201911080UTA.html',
#  '/boxscores/201911080POR.html',
#  '/boxscores/201911080LAL.html',
#  '/boxscores/201911090SAS.html',
#  '/boxscores/201911090CHO.html',
#  '/boxscores/201911090CHI.html',
#  '/boxscores/201911090MEM.html',
#  '/boxscores/201911090OKC.html',
#  '/boxscores/201911100MIN.html',
#  '/boxscores/201911100ORL.html',
#  '/boxscores/201911100PHI.html',
#  '/boxscores/201911100OKC.html',
#  '/boxscores/201911100NYK.html',
#  '/boxscores/201911100PHO.html',
#  '/boxscores/201911100POR.html',
#  '/boxscores/201911100LAL.html',
#  '/boxscores/201911110DET.html',
#  '/boxscores/201911110BOS.html',
#  '/boxscores/201911110SAS.html',
#  '/boxscores/201911110NOP.html',
#  '/boxscores/201911110GSW.html',
#  '/boxscores/201911110LAC.html',
#  '/boxscores/201911120IND.html',
#  '/boxscores/201911120PHI.html',
#  '/boxscores/201911120MIA.html',
#  '/boxscores/201911120CHI.html',
#  '/boxscores/201911120DEN.html',
#  '/boxscores/201911120PHO.html',
#  '/boxscores/201911120UTA.html',
#  '/boxscores/201911120SAC.html',
#  '/boxscores/201911130CHO.html',
#  '/boxscores/201911130ORL.html',
#  '/boxscores/201911130BOS.html',
#  '/boxscores/201911130HOU.html',
#  '/boxscores/201911130MIN.html',
#  '/boxscores/201911130LAL.html',
#  '/boxscores/201911130POR.html',
#  '/boxscores/201911140CLE.html',
#  '/boxscores/201911140MIL.html',
#  '/boxscores/201911140NOP.html',
#  '/boxscores/201911140NYK.html',
#  '/boxscores/201911140PHO.html',
#  '/boxscores/201911140DEN.html',
#  '/boxscores/201911150CHO.html',
#  '/boxscores/201911150ORL.html',
#  '/boxscores/201911150HOU.html',
#  '/boxscores/201911150MEM.html',
#  '/boxscores/201911150MIN.html',
#  '/boxscores/201911150OKC.html',
#  '/boxscores/201911150GSW.html',
#  '/boxscores/201911150LAL.html',
#  '/boxscores/201911160CHI.html',
#  '/boxscores/201911160IND.html',
#  '/boxscores/201911160NYK.html',
#  '/boxscores/201911160MIA.html',
#  '/boxscores/201911160MIN.html',
#  '/boxscores/201911160DAL.html',
#  '/boxscores/201911160SAS.html',
#  '/boxscores/201911160LAC.html',
#  '/boxscores/201911170CLE.html',
#  '/boxscores/201911170SAC.html',
#  '/boxscores/201911170MEM.html',
#  '/boxscores/201911170ORL.html',
#  '/boxscores/201911170NOP.html',
#  '/boxscores/201911170LAL.html',
#  '/boxscores/201911180NYK.html',
#  '/boxscores/201911180BRK.html',
#  '/boxscores/201911180TOR.html',
#  '/boxscores/201911180CHI.html',
#  '/boxscores/201911180HOU.html',
#  '/boxscores/201911180DAL.html',
#  '/boxscores/201911180PHO.html',
#  '/boxscores/201911180UTA.html',
#  '/boxscores/201911180LAC.html',
#  '/boxscores/201911190MEM.html',
#  '/boxscores/201911190NOP.html',
#  '/boxscores/201911190SAC.html',
#  '/boxscores/201911190LAL.html',
#  '/boxscores/201911200PHI.html',
#  '/boxscores/201911200WAS.html',
#  '/boxscores/201911200ATL.html',
#  '/boxscores/201911200BRK.html',
#  '/boxscores/201911200DAL.html',
#  '/boxscores/201911200MIA.html',
#  '/boxscores/201911200TOR.html',
#  '/boxscores/201911200CHI.html',
#  '/boxscores/201911200MIN.html',
#  '/boxscores/201911200DEN.html',
#  '/boxscores/201911200LAC.html',
#  '/boxscores/201911210MIL.html',
#  '/boxscores/201911210PHO.html',
#  '/boxscores/201911220DET.html',
#  '/boxscores/201911220WAS.html',
#  '/boxscores/201911220BRK.html',
#  '/boxscores/201911220CHI.html',
#  '/boxscores/201911220OKC.html',
#  '/boxscores/201911220PHI.html',
#  '/boxscores/201911220DAL.html',
#  '/boxscores/201911220DEN.html',
#  '/boxscores/201911220UTA.html',
#  '/boxscores/201911220LAC.html',
#  '/boxscores/201911230MIN.html',
#  '/boxscores/201911230CHO.html',
#  '/boxscores/201911230IND.html',
#  '/boxscores/201911230ATL.html',
#  '/boxscores/201911230NYK.html',
#  '/boxscores/201911230PHI.html',
#  '/boxscores/201911230CLE.html',
#  '/boxscores/201911230MEM.html',
#  '/boxscores/201911230MIL.html',
#  '/boxscores/201911230UTA.html',
#  '/boxscores/201911240HOU.html',
#  '/boxscores/201911240NYK.html',
#  '/boxscores/201911240WAS.html',
#  '/boxscores/201911240DEN.html',
#  '/boxscores/201911240LAC.html',
#  '/boxscores/201911250CLE.html',
#  '/boxscores/201911250DET.html',
#  '/boxscores/201911250IND.html',
#  '/boxscores/201911250ATL.html',
#  '/boxscores/201911250BOS.html',
#  '/boxscores/201911250MIA.html',
#  '/boxscores/201911250TOR.html',
#  '/boxscores/201911250CHI.html',
#  '/boxscores/201911250MIL.html',
#  '/boxscores/201911250SAS.html',
#  '/boxscores/201911250GSW.html',
#  '/boxscores/201911260DAL.html',
#  '/boxscores/201911260DEN.html',
#  '/boxscores/201911270BOS.html',
#  '/boxscores/201911270CHO.html',
#  '/boxscores/201911270CLE.html',
#  '/boxscores/201911270IND.html',
#  '/boxscores/201911270PHI.html',
#  '/boxscores/201911270TOR.html',
#  '/boxscores/201911270HOU.html',
#  '/boxscores/201911270MEM.html',
#  '/boxscores/201911270MIL.html',
#  '/boxscores/201911270SAS.html',
#  '/boxscores/201911270PHO.html',
#  '/boxscores/201911270NOP.html',
#  '/boxscores/201911270POR.html',
#  '/boxscores/201911270GSW.html',
#  '/boxscores/201911290BRK.html',
#  '/boxscores/201911290DET.html',
#  '/boxscores/201911290ORL.html',
#  '/boxscores/201911290CLE.html',
#  '/boxscores/201911290NYK.html',
#  '/boxscores/201911290IND.html',
#  '/boxscores/201911290MEM.html',
#  '/boxscores/201911290MIA.html',
#  '/boxscores/201911290OKC.html',
#  '/boxscores/201911290SAS.html',
#  '/boxscores/201911290PHO.html',
#  '/boxscores/201911290POR.html',
#  '/boxscores/201911290LAL.html',
#  '/boxscores/201911300SAC.html',
#  '/boxscores/201911300PHI.html',
#  '/boxscores/201911300HOU.html',
#  '/boxscores/201911300MIL.html',
#  '/boxscores/201912010BRK.html',
#  '/boxscores/201912010MIN.html',
#  '/boxscores/201912010NYK.html',
#  '/boxscores/201912010LAL.html',
#  '/boxscores/201912010DET.html',
#  '/boxscores/201912010NOP.html',
#  '/boxscores/201912010ORL.html',
#  '/boxscores/201912010TOR.html',
#  '/boxscores/201912010LAC.html',
#  '/boxscores/201912020CHO.html',
#  '/boxscores/201912020PHI.html',
#  '/boxscores/201912020ATL.html',
#  '/boxscores/201912020MEM.html',
#  '/boxscores/201912020MIL.html',
#  '/boxscores/201912020SAC.html',
#  '/boxscores/201912030CLE.html',
#  '/boxscores/201912030WAS.html',
#  '/boxscores/201912030NOP.html',
#  '/boxscores/201912030TOR.html',
#  '/boxscores/201912030SAS.html',
#  '/boxscores/201912030DEN.html',
#  '/boxscores/201912030LAC.html',
#  '/boxscores/201912040CHO.html',
#  '/boxscores/201912040DET.html',
#  '/boxscores/201912040ORL.html',
#  '/boxscores/201912040ATL.html',
#  '/boxscores/201912040BOS.html',
#  '/boxscores/201912040CHI.html',
#  '/boxscores/201912040OKC.html',
#  '/boxscores/201912040DAL.html',
#  '/boxscores/201912040UTA.html',
#  '/boxscores/201912040POR.html',
#  '/boxscores/201912050WAS.html',
#  '/boxscores/201912050NYK.html',
#  '/boxscores/201912050TOR.html',
#  '/boxscores/201912050NOP.html',
#  '/boxscores/201912060CHO.html',
#  '/boxscores/201912060CLE.html',
#  '/boxscores/201912060DET.html',
#  '/boxscores/201912060BOS.html',
#  '/boxscores/201912060CHI.html',
#  '/boxscores/201912060MIA.html',
#  '/boxscores/201912060OKC.html',
#  '/boxscores/201912060MIL.html',
#  '/boxscores/201912060SAS.html',
#  '/boxscores/201912060POR.html',
#  '/boxscores/201912070DAL.html',
#  '/boxscores/201912070NYK.html',
#  '/boxscores/201912070PHI.html',
#  '/boxscores/201912070HOU.html',
#  '/boxscores/201912070UTA.html',
#  '/boxscores/201912080BRK.html',
#  '/boxscores/201912080CHO.html',
#  '/boxscores/201912080MIA.html',
#  '/boxscores/201912080PHI.html',
#  '/boxscores/201912080WAS.html',
#  '/boxscores/201912080DAL.html',
#  '/boxscores/201912080POR.html',
#  '/boxscores/201912080LAL.html',
#  '/boxscores/201912090IND.html',
#  '/boxscores/201912090BOS.html',
#  '/boxscores/201912090CHI.html',
#  '/boxscores/201912090HOU.html',
#  '/boxscores/201912090MIL.html',
#  '/boxscores/201912090NOP.html',
#  '/boxscores/201912090PHO.html',
#  '/boxscores/201912090UTA.html',
#  '/boxscores/201912090GSW.html',
#  '/boxscores/201912100CHO.html',
#  '/boxscores/201912100MIA.html',
#  '/boxscores/201912100PHI.html',
#  '/boxscores/201912100POR.html',
#  '/boxscores/201912110CLE.html',
#  '/boxscores/201912110IND.html',
#  '/boxscores/201912110ORL.html',
#  '/boxscores/201912110TOR.html',
#  '/boxscores/201912110BRK.html',
#  '/boxscores/201912110CHI.html',
#  '/boxscores/201912110MIN.html',
#  '/boxscores/201912110PHO.html',
#  '/boxscores/201912110MIL.html',
#  '/boxscores/201912110SAC.html',
#  '/boxscores/201912110GSW.html',
#  '/boxscores/201912120BOS.html',
#  '/boxscores/201912120SAS.html',
#  '/boxscores/201912120DET.html',
#  '/boxscores/201912120DEN.html',
#  '/boxscores/201912130MIA.html',
#  '/boxscores/201912130ORL.html',
#  '/boxscores/201912130PHI.html',
#  '/boxscores/201912130ATL.html',
#  '/boxscores/201912130CHI.html',
#  '/boxscores/201912130MEM.html',
#  '/boxscores/201912130UTA.html',
#  '/boxscores/201912130MIN.html',
#  '/boxscores/201912130SAC.html',
#  '/boxscores/201912140PHO.html',
#  '/boxscores/201912140TOR.html',
#  '/boxscores/201912140CHI.html',
#  '/boxscores/201912140MEM.html',
#  '/boxscores/201912140DAL.html',
#  '/boxscores/201912140MIL.html',
#  '/boxscores/201912140DEN.html',
#  '/boxscores/201912140HOU.html',
#  '/boxscores/201912150NOP.html',
#  '/boxscores/201912150IND.html',
#  '/boxscores/201912150ATL.html',
#  '/boxscores/201912150BRK.html',
#  '/boxscores/201912150DEN.html',
#  '/boxscores/201912150GSW.html',
#  '/boxscores/201912160DET.html',
#  '/boxscores/201912160TOR.html',
#  '/boxscores/201912160HOU.html',
#  '/boxscores/201912160MEM.html',
#  '/boxscores/201912160MIL.html',
#  '/boxscores/201912160OKC.html',
#  '/boxscores/201912160PHO.html',
#  '/boxscores/201912170CHO.html',
#  '/boxscores/201912170IND.html',
#  '/boxscores/201912170NYK.html',
#  '/boxscores/201912170NOP.html',
#  '/boxscores/201912170UTA.html',
#  '/boxscores/201912170LAC.html']

# %%
url = 'https://www.basketball-reference.com/boxscores/201910220LAC.html'
html = urlopen(url)
soup = BeautifulSoup(html, 'lxml')

def get_game_score(soup):
    for tr in soup.find_all(id='all_line_score'):
        comment = tr.find(text=lambda text:isinstance(text, Comment))
        commentsoup = BeautifulSoup(comment ,'lxml')
    rows = commentsoup.findAll('tr')
    game_score = [[td.getText() for td in rows[i].findAll('td')]
                for i in range(len(rows))]
    game_score = [score for score in game_score if len(score) > 0]

    header = [[td.getText() for td in rows[i].findAll('th')]
                for i in range(1,len(rows))]
    header = [head for head in header if len(head) > 0]
    header = header[0]
    teamA = game_score[0][0]
    teamH = game_score[1][0]
    return pd.DataFrame(game_score, columns=header).set_index('\xa0'), teamA, teamH

def get_players_score(team):
    id_str = "box-"+str(team)+"-game-basic"
    soup2 = soup.find_all(id=id_str)
    player_stats = [[td.getText() for td in soup2[0].find_all('tr')[i:][0].find_all('td')]
                for i in range(2,len(soup2[0].find_all('tr'))-1)]
    player_names = [[td.getText() for td in soup2[i].find_all('a')]
                for i in range(len(soup2))]
    player_names = [name.replace('.','') for name in player_names[0]]
    player_stats = [player for player in player_stats if len(player) > 0]
    headers = [th.getText() for th in soup.findAll('tr')[1].findAll('th')]
    box_score = pd.DataFrame(player_stats, columns=headers[1:], index = player_names)
    return box_score


game_df, teamA, teamH = get_game_score(soup)
teamA_stats = get_players_score(teamA)
teamH_stats = get_players_score(teamH)

print(game_df)
print(teamA_stats)
# Out:
#       1   2   3   4    T
#
# LAL  25  29  31  17  102
# LAC  22  40  23  27  112
#                                     MP    FG   FGA    FG%    3P   3PA    3P%  \
# Anthony Davis                    37:22     8    21   .381     0     2   .000
# LeBron James                     36:00     7    19   .368     1     5   .200
# Danny Green                      32:20    10    14   .714     7     9   .778
# Avery Bradley                    24:02     3     7   .429     2     5   .400
# JaVale McGee                     17:20     2     3   .667     0     0
# Kentavious Caldwell-Pope         27:23     0     3   .000     0     2   .000
# Dwight Howard                    19:02     1     3   .333     0     0
# Quinn Cook                       16:56     2     7   .286     0     3   .000
# Troy Daniels                     16:14     2     6   .333     1     5   .200
# Jared Dudley                     13:21     2     2  1.000     2     2  1.000
# Alex Caruso               Did Not Play  None  None   None  None  None   None
# Zach Norvell              Did Not Play  None  None   None  None  None   None
# Kostas Antetokounmpo      Did Not Play  None  None   None  None  None   None
#
#                             FT   FTA    FT%   ORB   DRB   TRB   AST   STL  \
# Anthony Davis                9    14   .643     3     6     9     5     1
# LeBron James                 3     4   .750     1     9    10     8     1
# Danny Green                  1     1  1.000     1     6     7     0     2
# Avery Bradley                0     0            0     3     3     0     0
# JaVale McGee                 0     0            1     1     2     0     0
# Kentavious Caldwell-Pope     0     0            0     3     3     3     0
# Dwight Howard                1     1  1.000     3     3     6     1     0
# Quinn Cook                   0     0            0     1     1     2     0
# Troy Daniels                 1     1  1.000     0     0     0     1     0
# Jared Dudley                 0     0            0     0     0     0     0
# Alex Caruso               None  None   None  None  None  None  None  None
# Zach Norvell              None  None   None  None  None  None  None  None
# Kostas Antetokounmpo      None  None   None  None  None  None  None  None
#
#                            BLK   TOV    PF   PTS   +/-
# Anthony Davis                2     3     3    25    +3
# LeBron James                 1     5     3    18    -8
# Danny Green                  1     0     3    28    +7
# Avery Bradley                0     2     3     8    -1
# JaVale McGee                 2     1     0     4     0
# Kentavious Caldwell-Pope     0     1     5     0    -8
# Dwight Howard                1     0     4     3    -1
# Quinn Cook                   0     1     0     4    -9
# Troy Daniels                 0     1     1     6   -13
# Jared Dudley                 0     0     2     6   -20
# Alex Caruso               None  None  None  None  None
# Zach Norvell              None  None  None  None  None
# Kostas Antetokounmpo      None  None  None  None  None

# %%
games_dict_list = []
game_id = url[-17:-5]
game_date = url[-17:-9]
game_dict = {'game_id':game_id, 'game_date':game_date, 'teamA':teamA,
             'teamH':teamH, 'game_score':game_df.to_dict(orient='index'),
            'teamA_stats':teamA_stats.to_dict(orient='index'),
            'teamH_stats':teamH_stats.to_dict(orient='index')}
games_dict_list.append(game_dict)
games_dict_list
# Out:
# [{'game_id': '201910220LAC',
#   'game_date': '20191022',
#   'teamA': 'LAL',
#   'teamH': 'LAC',
#   'game_score': {'LAL': {'1': '25',
#     '2': '29',
#     '3': '31',
#     '4': '17',
#     'T': '102'},
#    'LAC': {'1': '22', '2': '40', '3': '23', '4': '27', 'T': '112'}},
#   'teamA_stats': {'Anthony Davis': {'MP': '37:22',
#     'FG': '8',
#     'FGA': '21',
#     'FG%': '.381',
#     '3P': '0',
#     '3PA': '2',
#     '3P%': '.000',
#     'FT': '9',
#     'FTA': '14',
#     'FT%': '.643',
#     'ORB': '3',
#     'DRB': '6',
#     'TRB': '9',
#     'AST': '5',
#     'STL': '1',
#     'BLK': '2',
#     'TOV': '3',
#     'PF': '3',
#     'PTS': '25',
#     '+/-': '+3'},
#    'LeBron James': {'MP': '36:00',
#     'FG': '7',
#     'FGA': '19',
#     'FG%': '.368',
#     '3P': '1',
#     '3PA': '5',
#     '3P%': '.200',
#     'FT': '3',
#     'FTA': '4',
#     'FT%': '.750',
#     'ORB': '1',
#     'DRB': '9',
#     'TRB': '10',
#     'AST': '8',
#     'STL': '1',
#     'BLK': '1',
#     'TOV': '5',
#     'PF': '3',
#     'PTS': '18',
#     '+/-': '-8'},
#    'Danny Green': {'MP': '32:20',
#     'FG': '10',
#     'FGA': '14',
#     'FG%': '.714',
#     '3P': '7',
#     '3PA': '9',
#     '3P%': '.778',
#     'FT': '1',
#     'FTA': '1',
#     'FT%': '1.000',
#     'ORB': '1',
#     'DRB': '6',
#     'TRB': '7',
#     'AST': '0',
#     'STL': '2',
#     'BLK': '1',
#     'TOV': '0',
#     'PF': '3',
#     'PTS': '28',
#     '+/-': '+7'},
#    'Avery Bradley': {'MP': '24:02',
#     'FG': '3',
#     'FGA': '7',
#     'FG%': '.429',
#     '3P': '2',
#     '3PA': '5',
#     '3P%': '.400',
#     'FT': '0',
#     'FTA': '0',
#     'FT%': '',
#     'ORB': '0',
#     'DRB': '3',
#     'TRB': '3',
#     'AST': '0',
#     'STL': '0',
#     'BLK': '0',
#     'TOV': '2',
#     'PF': '3',
#     'PTS': '8',
#     '+/-': '-1'},
#    'JaVale McGee': {'MP': '17:20',
#     'FG': '2',
#     'FGA': '3',
#     'FG%': '.667',
#     '3P': '0',
#     '3PA': '0',
#     '3P%': '',
#     'FT': '0',
#     'FTA': '0',
#     'FT%': '',
#     'ORB': '1',
#     'DRB': '1',
#     'TRB': '2',
#     'AST': '0',
#     'STL': '0',
#     'BLK': '2',
#     'TOV': '1',
#     'PF': '0',
#     'PTS': '4',
#     '+/-': '0'},
#    'Kentavious Caldwell-Pope': {'MP': '27:23',
#     'FG': '0',
#     'FGA': '3',
#     'FG%': '.000',
#     '3P': '0',
#     '3PA': '2',
#     '3P%': '.000',
#     'FT': '0',
#     'FTA': '0',
#     'FT%': '',
#     'ORB': '0',
#     'DRB': '3',
#     'TRB': '3',
#     'AST': '3',
#     'STL': '0',
#     'BLK': '0',
#     'TOV': '1',
#     'PF': '5',
#     'PTS': '0',
#     '+/-': '-8'},
#    'Dwight Howard': {'MP': '19:02',
#     'FG': '1',
#     'FGA': '3',
#     'FG%': '.333',
#     '3P': '0',
#     '3PA': '0',
#     '3P%': '',
#     'FT': '1',
#     'FTA': '1',
#     'FT%': '1.000',
#     'ORB': '3',
#     'DRB': '3',
#     'TRB': '6',
#     'AST': '1',
#     'STL': '0',
#     'BLK': '1',
#     'TOV': '0',
#     'PF': '4',
#     'PTS': '3',
#     '+/-': '-1'},
#    'Quinn Cook': {'MP': '16:56',
#     'FG': '2',
#     'FGA': '7',
#     'FG%': '.286',
#     '3P': '0',
#     '3PA': '3',
#     '3P%': '.000',
#     'FT': '0',
#     'FTA': '0',
#     'FT%': '',
#     'ORB': '0',
#     'DRB': '1',
#     'TRB': '1',
#     'AST': '2',
#     'STL': '0',
#     'BLK': '0',
#     'TOV': '1',
#     'PF': '0',
#     'PTS': '4',
#     '+/-': '-9'},
#    'Troy Daniels': {'MP': '16:14',
#     'FG': '2',
#     'FGA': '6',
#     'FG%': '.333',
#     '3P': '1',
#     '3PA': '5',
#     '3P%': '.200',
#     'FT': '1',
#     'FTA': '1',
#     'FT%': '1.000',
#     'ORB': '0',
#     'DRB': '0',
#     'TRB': '0',
#     'AST': '1',
#     'STL': '0',
#     'BLK': '0',
#     'TOV': '1',
#     'PF': '1',
#     'PTS': '6',
#     '+/-': '-13'},
#    'Jared Dudley': {'MP': '13:21',
#     'FG': '2',
#     'FGA': '2',
#     'FG%': '1.000',
#     '3P': '2',
#     '3PA': '2',
#     '3P%': '1.000',
#     'FT': '0',
#     'FTA': '0',
#     'FT%': '',
#     'ORB': '0',
#     'DRB': '0',
#     'TRB': '0',
#     'AST': '0',
#     'STL': '0',
#     'BLK': '0',
#     'TOV': '0',
#     'PF': '2',
#     'PTS': '6',
#     '+/-': '-20'},
#    'Alex Caruso': {'MP': 'Did Not Play',
#     'FG': None,
#     'FGA': None,
#     'FG%': None,
#     '3P': None,
#     '3PA': None,
#     '3P%': None,
#     'FT': None,
#     'FTA': None,
#     'FT%': None,
#     'ORB': None,
#     'DRB': None,
#     'TRB': None,
#     'AST': None,
#     'STL': None,
#     'BLK': None,
#     'TOV': None,
#     'PF': None,
#     'PTS': None,
#     '+/-': None},
#    'Zach Norvell': {'MP': 'Did Not Play',
#     'FG': None,
#     'FGA': None,
#     'FG%': None,
#     '3P': None,
#     '3PA': None,
#     '3P%': None,
#     'FT': None,
#     'FTA': None,
#     'FT%': None,
#     'ORB': None,
#     'DRB': None,
#     'TRB': None,
#     'AST': None,
#     'STL': None,
#     'BLK': None,
#     'TOV': None,
#     'PF': None,
#     'PTS': None,
#     '+/-': None},
#    'Kostas Antetokounmpo': {'MP': 'Did Not Play',
#     'FG': None,
#     'FGA': None,
#     'FG%': None,
#     '3P': None,
#     '3PA': None,
#     '3P%': None,
#     'FT': None,
#     'FTA': None,
#     'FT%': None,
#     'ORB': None,
#     'DRB': None,
#     'TRB': None,
#     'AST': None,
#     'STL': None,
#     'BLK': None,
#     'TOV': None,
#     'PF': None,
#     'PTS': None,
#     '+/-': None}},
#   'teamH_stats': {'Kawhi Leonard': {'MP': '31:33',
#     'FG': '10',
#     'FGA': '19',
#     'FG%': '.526',
#     '3P': '1',
#     '3PA': '5',
#     '3P%': '.200',
#     'FT': '9',
#     'FTA': '10',
#     'FT%': '.900',
#     'ORB': '1',
#     'DRB': '5',
#     'TRB': '6',
#     'AST': '5',
#     'STL': '2',
#     'BLK': '1',
#     'TOV': '6',
#     'PF': '5',
#     'PTS': '30',
#     '+/-': '+5'},
#    'Patrick Beverley': {'MP': '31:22',
#     'FG': '1',
#     'FGA': '7',
#     'FG%': '.143',
#     '3P': '0',
#     '3PA': '5',
#     '3P%': '.000',
#     'FT': '0',
#     'FTA': '0',
#     'FT%': '',
#     'ORB': '2',
#     'DRB': '8',
#     'TRB': '10',
#     'AST': '6',
#     'STL': '0',
#     'BLK': '1',
#     'TOV': '2',
#     'PF': '4',
#     'PTS': '2',
#     '+/-': '+13'},
#    'Landry Shamet': {'MP': '26:26',
#     'FG': '3',
#     'FGA': '8',
#     'FG%': '.375',
#     '3P': '2',
#     '3PA': '4',
#     '3P%': '.500',
#     'FT': '0',
#     'FTA': '0',
#     'FT%': '',
#     'ORB': '0',
#     'DRB': '3',
#     'TRB': '3',
#     'AST': '2',
#     'STL': '0',
#     'BLK': '0',
#     'TOV': '0',
#     'PF': '1',
#     'PTS': '8',
#     '+/-': '-1'},
#    'Patrick Patterson': {'MP': '17:29',
#     'FG': '1',
#     'FGA': '3',
#     'FG%': '.333',
#     '3P': '1',
#     '3PA': '3',
#     '3P%': '.333',
#     'FT': '1',
#     'FTA': '2',
#     'FT%': '.500',
#     'ORB': '1',
#     'DRB': '2',
#     'TRB': '3',
#     'AST': '0',
#     'STL': '0',
#     'BLK': '0',
#     'TOV': '0',
#     'PF': '2',
#     'PTS': '4',
#     '+/-': '-2'},
#    'Ivica Zubac': {'MP': '9:38',
#     'FG': '4',
#     'FGA': '4',
#     'FG%': '1.000',
#     '3P': '0',
#     '3PA': '0',
#     '3P%': '',
#     'FT': '0',
#     'FTA': '0',
#     'FT%': '',
#     'ORB': '1',
#     'DRB': '0',
#     'TRB': '1',
#     'AST': '0',
#     'STL': '0',
#     'BLK': '0',
#     'TOV': '0',
#     'PF': '2',
#     'PTS': '8',
#     '+/-': '-5'},
#    'Montrezl Harrell': {'MP': '38:22',
#     'FG': '7',
#     'FGA': '11',
#     'FG%': '.636',
#     '3P': '0',
#     '3PA': '0',
#     '3P%': '',
#     'FT': '3',
#     'FTA': '8',
#     'FT%': '.375',
#     'ORB': '2',
#     'DRB': '5',
#     'TRB': '7',
#     'AST': '4',
#     'STL': '1',
#     'BLK': '1',
#     'TOV': '3',
#     'PF': '3',
#     'PTS': '17',
#     '+/-': '+15'},
#    'Lou Williams': {'MP': '36:44',
#     'FG': '8',
#     'FGA': '14',
#     'FG%': '.571',
#     '3P': '1',
#     '3PA': '4',
#     '3P%': '.250',
#     'FT': '4',
#     'FTA': '4',
#     'FT%': '1.000',
#     'ORB': '1',
#     'DRB': '4',
#     'TRB': '5',
#     'AST': '7',
#     'STL': '1',
#     'BLK': '0',
#     'TOV': '2',
#     'PF': '0',
#     'PTS': '21',
#     '+/-': '+13'},
#    'Maurice Harkless': {'MP': '29:10',
#     'FG': '4',
#     'FGA': '7',
#     'FG%': '.571',
#     '3P': '2',
#     '3PA': '3',
#     '3P%': '.667',
#     'FT': '0',
#     'FTA': '0',
#     'FT%': '',
#     'ORB': '2',
#     'DRB': '2',
#     'TRB': '4',
#     'AST': '0',
#     'STL': '4',
#     'BLK': '2',
#     'TOV': '0',
#     'PF': '5',
#     'PTS': '10',
#     '+/-': '+7'},
#    'JaMychal Green': {'MP': '19:16',
#     'FG': '4',
#     'FGA': '8',
#     'FG%': '.500',
#     '3P': '4',
#     '3PA': '7',
#     '3P%': '.571',
#     'FT': '0',
#     'FTA': '0',
#     'FT%': '',
#     'ORB': '1',
#     'DRB': '5',
#     'TRB': '6',
#     'AST': '0',
#     'STL': '0',
#     'BLK': '0',
#     'TOV': '1',
#     'PF': '3',
#     'PTS': '12',
#     '+/-': '+5'},
#    'Jerome Robinson': {'MP': 'Did Not Play',
#     'FG': None,
#     'FGA': None,
#     'FG%': None,
#     '3P': None,
#     '3PA': None,
#     '3P%': None,
#     'FT': None,
#     'FTA': None,
#     'FT%': None,
#     'ORB': None,
#     'DRB': None,
#     'TRB': None,
#     'AST': None,
#     'STL': None,
#     'BLK': None,
#     'TOV': None,
#     'PF': None,
#     'PTS': None,
#     '+/-': None},
#    'Mfiondu Kabengele': {'MP': 'Did Not Play',
#     'FG': None,
#     'FGA': None,
#     'FG%': None,
#     '3P': None,
#     '3PA': None,
#     '3P%': None,
#     'FT': None,
#     'FTA': None,
#     'FT%': None,
#     'ORB': None,
#     'DRB': None,
#     'TRB': None,
#     'AST': None,
#     'STL': None,
#     'BLK': None,
#     'TOV': None,
#     'PF': None,
#     'PTS': None,
#     '+/-': None},
#    'Terance Mann': {'MP': 'Did Not Play',
#     'FG': None,
#     'FGA': None,
#     'FG%': None,
#     '3P': None,
#     '3PA': None,
#     '3P%': None,
#     'FT': None,
#     'FTA': None,
#     'FT%': None,
#     'ORB': None,
#     'DRB': None,
#     'TRB': None,
#     'AST': None,
#     'STL': None,
#     'BLK': None,
#     'TOV': None,
#     'PF': None,
#     'PTS': None,
#     '+/-': None},
#    'Johnathan Motley': {'MP': 'Did Not Play',
#     'FG': None,
#     'FGA': None,
#     'FG%': None,
#     '3P': None,
#     '3PA': None,
#     '3P%': None,
#     'FT': None,
#     'FTA': None,
#     'FT%': None,
#     'ORB': None,
#     'DRB': None,
#     'TRB': None,
#     'AST': None,
#     'STL': None,
#     'BLK': None,
#     'TOV': None,
#     'PF': None,
#     'PTS': None,
#     '+/-': None}}}]

# %%
def get_new_games(database = 'season2020', season = 2020):
    client = pymongo.MongoClient("localhost", 27017)
    db = client[database]
    cursor = db.games.find({},{"game_id":1,"_id":False})
    old_games = ['/boxscores/' + doc['game_id'] + '.html' for doc in cursor]
    link_months = get_months(season)
    games = [] #list for the url for all games of the season
    for i in link_months:
        games = games + get_list_of_games(i)
    games = [game for game in games if game not in old_games]
    return games

# %%
def update_database(games, database = 'season2020'):
    client = pymongo.MongoClient("localhost", 27017)
    db = client[database]
    games_dict_list = []
    for i in range(len(games)):
        url = "https://www.basketball-reference.com" + games[i]
        html = urlopen(url)
        soup = BeautifulSoup(html, 'lxml')
        game_df, teamA, teamH = get_game_score(soup)
        teamA_stats = get_players_score(teamA)
        teamH_stats = get_players_score(teamH)
        game_id = url[-17:-5]
        game_date = url[-17:-9]
        game_dict = {'game_id':game_id, 'game_date':game_date, 'teamA':teamA,
                     'teamH':teamH, 'game_score':game_df.to_dict(orient='index'),
                    'teamA_stats':teamA_stats.to_dict(orient='index'),
                    'teamH_stats':teamH_stats.to_dict(orient='index')}
        games_dict_list.append(game_dict)
    db.games.insert_many(games_dict_list)
    return print('Done'), print(db.games.count_documents({}))

# %% [markdown]
# # Part 2 - Get data from database

# %%
client = pymongo.MongoClient("localhost", 27017)
db = client['season2020']

# %%
def list_of_names():
    cursor2 = db.games.find({},{"teamA":1,"teamA_stats":1,"_id":False})
    c = pd.DataFrame(cursor2)
    total_players = pd.DataFrame()
    for j in range(len(c)):
        players = c.to_dict(orient='split')['data'][j][1]
        team = c.to_dict(orient='split')['data'][j][0]
        name_players = [name for name in pd.DataFrame(players).columns]
        team_list = [team for i in range(len(pd.DataFrame(players).columns))]
        total_players = total_players.append(pd.DataFrame({'Players':name_players, 'Team':team_list}),ignore_index=True)
        total_players1 = total_players.drop_duplicates(subset ="Players", keep = 'first', inplace = False)
    return total_players1

total_players = list_of_names()
total_players
# Out:
#                   Players Team
# 0            Jrue Holiday  NOP
# 1          Brandon Ingram  NOP
# 2               JJ Redick  NOP
# 3              Lonzo Ball  NOP
# 4          Derrick Favors  NOP
# ...                   ...  ...
# 4463       Romeo Langford  BOS
# 4474  Talen Horton-Tucker  LAL
# 4861      Jalen McDaniels  CHO
# 4989    Cristiano Felício  CHI
# 5026       Devontae Cacok  LAL
#
# [471 rows x 2 columns]

# %%
def get_team_totals():
    cursor3 = db.games.find({}).limit(10)
    list_games = [i for i in cursor3]
    store_df = pd.DataFrame()
    for match in list_games:
        game_id = match['game_id']
        date = match['game_date']
        team_a =  match['teamA']
        team_b =  match['teamH']
    
        df_a = pd.DataFrame.from_dict(match['teamA_stats'], orient='index')
        df_a.dropna(inplace=True)
        df_b = pd.DataFrame.from_dict(match['teamH_stats'], orient='index')
        df_b.dropna(inplace=True)
        df_a['Away'] = 1
        df_b['Away'] = 0
    
        col_stats = ['PTS','FG','FGA','3P','3PA', 'FT', 'FTA',
                     'TRB', 'AST', 'STL', 'BLK', 'TOV' ]
    
        df_a = pd.DataFrame(df_a[col_stats].astype('int32').sum())
        df_a.columns = [team_a]
        df_b = pd.DataFrame(df_b[col_stats].astype('int32').sum())
        df_b.columns = [team_b]
        df_a.loc['Opp',:]=team_b
        df_b.loc['Opp',:]=team_a
    
        totals = pd.concat([df_a, df_b], axis=1, sort=False)
        totals = totals.transpose()
    
        store_df = pd.concat([store_df,totals])
    return store_df

get_team_totals()
# Out:
#      PTS  FG  FGA  3P 3PA  FT FTA TRB AST STL BLK TOV  Opp
# NOP  122  43  102  19  45  17  20  53  30   4   9  19  TOR
# TOR  130  42  103  14  40  32  38  57  23   7   3  16  NOP
# LAL  102  37   85  13  33  15  21  41  20   4   7  14  LAC
# LAC  112  42   81  11  31  17  24  45  24   8   5  14  LAL
# CHI  125  49  105   9  30  18  22  49  25  11   4  10  CHO
# CHO  126  45   88  23  44  13  16  41  28   3   4  19  CHI
# DET  119  41   78  11  24  26  33  45  26   5   6  18  IND
# IND  110  41   89   8  21  20  24  36  26   8   6  15  DET
# CLE   85  33   88   9  34  10  15  54  20   8   2  16  ORL
# ORL   94  37   86   9  30  11  19  46  24  12   4  13  CLE
# MIN  127  46  108  13  43  22  28  52  23   9   4  13  BRK
# BRK  126  48  101  15  34  15  26  48  19   8   9  16  MIN
# MEM  101  38   89   5  32  20  30  40  22   9   7  24  MIA
# MIA  120  40   85   7  18  33  39  51  18   9   8  21  MEM
# BOS   93  33   90   7  26  20  34  41  18   4   2  10  PHI
# PHI  107  37   85   7  29  26  36  62  24   6   7  15  BOS
# WAS  100  37   93  11  41  15  18  47  26   6   3  17  DAL
# DAL  108  35   76  11  36  27  33  46  17   6   5  19  WAS
# NYK  111  44   94  10  30  13  18  39  24  16   1  14  SAS
# SAS  120  42   83   7  21  29  36  51  22   6   5  21  NYK

# %%
def player_avg_stat(player, stat):
    player = str(player)
    stat = str(stat)
    cursor = db.games.find({"teamA_stats."+player:{"$exists":True}},{"teamA_stats."+player+"."+stat:1,"_id":False})
    value = [doc['teamA_stats'][player][stat] for doc in cursor]
    cursor1 = db.games.find({"teamH_stats."+player:{"$exists":True}},{"teamH_stats."+player+"."+stat:1,"_id":False})
    value1 = [doc['teamH_stats'][player][stat] for doc in cursor1]
    values = value + value1
    num_values = [float(num) for num in values if (num is not None) and (num is not '')]
    stat_mean = np.array(num_values).mean().round(1)
    return player, stat, stat_mean

def get_avgs_dataframe():
    stats = ['PTS','FG','FGA','FG%','3P','3PA','3P%','FT','FTA','FT%','TRB','AST','STL','BLK','TOV','+/-']
    names = list(total_players['Players'])
    store = []
    final_list = []
    avg_stats = pd.DataFrame()
    for name in names:
        store = [name]
        for stat in stats:
            foo = player_avg_stat(name, stat)
            store = store + [foo[2]]
        final_list.append(store)
    return pd.DataFrame(final_list, columns=(['Players'] +stats)).sort_values('PTS', ascending=False)

get_avgs_dataframe().head(10)
# Out:
# /home/pedro/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: Mean of empty slice.
#   # Remove the CWD from sys.path while we load stuff.
# /home/pedro/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#                    Players   PTS    FG   FGA  FG%   3P   3PA  3P%    FT   FTA  \
# 373           James Harden  38.9  11.1  25.1  0.4  5.0  13.9  0.4  11.6  13.1
# 183  Giannis Antetokounmpo  31.7  11.7  20.8  0.6  1.6   5.1  0.3   6.6  11.0
# 221            Luka Dončić  29.3   9.4  19.6  0.5  3.0   9.3  0.3   7.4   9.2
# 342           Kyrie Irving  28.5  10.2  22.9  0.4  2.8   8.3  0.3   5.4   5.7
# 168             Trae Young  28.3   9.4  20.9  0.4  3.4   9.1  0.4   6.1   7.1
# 103           Bradley Beal  27.8   9.5  21.4  0.4  2.7   7.9  0.3   6.0   7.3
# 13           Anthony Davis  27.4   9.6  19.3  0.5  1.2   3.6  0.3   7.0   8.2
# 64      Karl-Anthony Towns  26.5   9.0  17.5  0.5  3.6   8.5  0.4   4.9   6.2
# 247         Damian Lillard  26.3   8.2  18.5  0.4  3.3   9.0  0.4   6.6   7.3
# 14            LeBron James  25.9  10.0  20.1  0.5  2.2   6.2  0.3   3.7   5.5
#
#      FT%   TRB   AST  STL  BLK  TOV   +/-
# 373  0.9   6.0   7.4  1.9  0.7  4.9   6.9
# 183  0.6  12.8   5.3  1.3  1.2  3.7  10.9
# 221  0.8   9.6   8.9  1.2  0.1  4.4   6.5
# 342  0.9   5.4   7.2  1.1  0.5  2.4  -0.8
# 168  0.9   4.2   8.5  1.2  0.1  4.8  -6.3
# 103  0.8   4.7   7.0  1.0  0.2  3.6  -5.4
# 13   0.9   9.3   3.3  1.5  2.6  2.3   6.2
# 64   0.8  11.7   4.4  1.0  1.3  3.1   0.3
# 247  0.9   4.3   7.4  1.0  0.4  2.9   2.2
# 14   0.7   7.4  10.6  1.2  0.6  4.0   8.9
